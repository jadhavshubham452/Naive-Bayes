# %% [markdown]
# # Naive Bayes

# %%
# Importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the datasets
data_train = pd.read_csv(r"D:\Excelr assignments\DS\Naive Bayes\SalaryData_Train.csv")
data_train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
data_train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
data_test = pd.read_csv(r"D:\Excelr assignments\DS\Naive Bayes\SalaryData_Test.csv")
data_test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
data_test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %% [markdown]
# # EDA and Data Preprocessing

# %%
data_train.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
data_test.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
data_train.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
data_test.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
data_train.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
data_test.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
data_train.shape
# Out:
# (30161, 14)

# %%
data_test.shape
# Out:
# (15060, 14)

# %%
string_columns = ['workclass','education','maritalstatus','occupation','relationship','race','sex','native']

# %% [markdown]
# # Graphical Visualization

# %%
sns.pairplot(data_train)
plt.show()

# %%
sns.pairplot(data_test)
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.boxplot(x='Salary', y='capitalgain', data=data_train)
plt.show()

# %%
sns.boxplot(x='Salary', y='capitalgain', data=data_test)
plt.show()

# %%
sns.countplot(x='Salary',data=data_train)
plt.show()

# %%
sns.countplot(x='Salary',data=data_test)
plt.show()

# %%
plt.figure(figsize=(18,10))
sns.barplot(x='Salary', y='hoursperweek', data=data_train)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.lmplot(y='capitalgain', x='hoursperweek',data=data_train)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.lmplot(y='capitalgain', x='hoursperweek',data=data_test)
plt.grid()
plt.show()

# %%
plt.subplots(1,2, figsize=(16,8))

colors = ["red", "blue"]
labels ="capitalgain", "capitalloss"

plt.suptitle('Salary of an individual', fontsize=12)

data_train["Salary"].value_counts().plot.pie(explode=[0,0.25], autopct='%1.2f%%', shadow=True, colors=colors, labels=labels, fontsize=10, startangle=2)
plt.grid()
plt.show()

# %%
plt.style.use('seaborn-whitegrid')

data_test.hist(bins=20, figsize=(15,10), color='red')
plt.show()

# %% [markdown]
# # Preprocessing

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()

# %%
for i in string_columns:
    data_train[i]=label_encoder.fit_transform(data_train[i])
    data_test[i]=label_encoder.fit_transform(data_test[i])

# %%
col_names=list(data_train.columns)
col_names
# Out:
# ['age',
#  'workclass',
#  'education',
#  'educationno',
#  'maritalstatus',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capitalgain',
#  'capitalloss',
#  'hoursperweek',
#  'native',
#  'Salary']

# %%
X_train=data_train[col_names[0:13]]
X_train
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# ...

# %%
Y_train=data_train[col_names[13]]
Y_train
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 30156     <=50K
# 30157      >50K
# 30158     <=50K
# 30159     <=50K
# 30160      >50K
# Name: Salary, Length: 30161, dtype: object

# %%
X_test=data_test[col_names[0:13]]
X_test
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# ...

# %%
Y_test=data_test[col_names[13]]
Y_test
# Out:
# 0         <=50K
# 1         <=50K
# 2          >50K
# 3          >50K
# 4         <=50K
#           ...
# 15055     <=50K
# 15056     <=50K
# 15057     <=50K
# 15058     <=50K
# 15059      >50K
# Name: Salary, Length: 15060, dtype: object

# %% [markdown]
# # Gaussian Naive Bayes  Model

# %%
from sklearn.naive_bayes import GaussianNB
Gnbmodel=GaussianNB()

# %%
train_pred_gnb=Gnbmodel.fit(X_train,Y_train).predict(X_train)
train_pred_gnb
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       dtype='<U6')

# %%
test_pred_gnb=Gnbmodel.fit(X_train,Y_train).predict(X_test)
test_pred_gnb
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' >50K', ' <=50K'],
#       dtype='<U6')

# %%
train_acc_gnb=np.mean(train_pred_gnb==Y_train)

# %%
test_acc_gnb=np.mean(test_pred_gnb==Y_test)

# %%
train_acc_gnb
# Out:
# 0.7953317197705646

# %%
test_acc_gnb
# Out:
# 0.7946879150066402

# %% [markdown]
# # Multinomial Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
Mnbmodel=MultinomialNB()

# %%
train_pred_multi=Mnbmodel.fit(X_train,Y_train).predict(X_train)
train_pred_multi
# Out:
# array([' >50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       dtype='<U6')

# %%
test_pred_multi=Mnbmodel.fit(X_train,Y_train).predict(X_test)
test_pred_multi
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' >50K', ' <=50K'],
#       dtype='<U6')

# %%
train_acc_multi=np.mean(train_pred_multi==Y_train)
train_acc_multi
# Out:
# 0.7729186698053778

# %%
test_acc_multi=np.mean(test_pred_multi==Y_test)
test_acc_multi
# Out:
# 0.7749667994687915
